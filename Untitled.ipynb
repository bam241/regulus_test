# %%
import cymetric
from cymetric import graphs
import sys
import os

sys.path.append(os.path.abspath("/Users/mouginot/work/helpmetric"))
import cymetrichelper as cyh
import pandahelper as pdh

import matplotlib as plt
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.data is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.material is not yet QA compliant.
#   return f(*args, **kwds)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: QAWarning: pyne.enrichment is not yet QA compliant.
#   return f(*args, **kwds)

# %%
    SMALL_SIZE = 40
    MEDIUM_SIZE = SMALL_SIZE+2
    BIGGER_SIZE = MEDIUM_SIZE +2

    plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
    plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
    plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
db = cymetric.evaluator.Evaluator(cymetric.dbopen("eg01-eg23_no_storing_legacy.h5"))

# %%
cymetric.graphs.flow_graph(db)

# %%
pool_to_sink = cyh.month2year(cymetric.timeseries.transactions(db, senders=['legacy_uox_pool'], receivers=['sink']))

# %%
pool_to_reprocessing = cyh.month2year(cymetric.timeseries.transactions(db, senders=['legacy_uox_pool'], receivers=['uox_reprocessing']))

# %%
e1x = pool_to_sink.plot(x="Time", y="Mass", marker = 'x', markersize=14, linestyle='-', color=None, mfc='none', linewidth=2.0, figsize = (20,12), label='Legacy To Sink')
pool_to_reprocessing.plot(x="Time", y="Mass", marker = 'x', markersize=14, linestyle='-', color=None, mfc='none', linewidth=2.0, ax=e1x, label='Legacy To Reprocessing')

# %%
db_waste = cymetric.evaluator.Evaluator(cymetric.dbopen("eg01-eg23_no_storing_legacy.h5"))

# %%
cymetric.graphs.flow_graph(db_waste)

# %%
pool_to_sink_2 = cyh.month2year(cymetric.timeseries.transactions(db_waste, senders=['legacy_uox_pool'], receivers=['sink']))

# %%
pool_to_reprocessing_2 = cyh.month2year(cymetric.timeseries.transactions(db_waste, senders=['legacy_uox_pool'], receivers=['uox_reprocessing']))

# %%
e2x = pool_to_sink_2.plot(x="Time", y="Mass", marker = 'x', markersize=14, linestyle='-', color=None, mfc='none', linewidth=2.0, figsize = (20,12), label='Legacy To Sink')
pool_to_reprocessing_2.plot(x="Time", y="Mass", marker = 'x', markersize=14, linestyle='-', color=None, mfc='none', linewidth=2.0, ax=e2x, label='Legacy To Reprocessing')
